# %% [markdown]
# # 1. Import Dependencies

# %%
import cv2
import os

# %% [markdown]
# # 2. Read in Image

# %%
# img_path = os.path.join('data', 'images', 'bike.png')
img_path = os.path.join('data', 'images', 'CanField', 'ISIC_0000000.jpg')

# %%
img = cv2.imread(img_path)
# print(img)

# %% [markdown]
# # 3. Render Image

# %%
# !pip install matplotlib

# %%
from matplotlib import pyplot as plt

# %%
# Show image
plt.imshow(img)

# %%
# reOrder Color Channels from OpenComputerVision to MatPlot Library
recolor = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(recolor)
plt.show()

# %% [markdown]
# # 4. Write out Image

# %%
cv2.imwrite('grayimage.png', gray)

# %%
output_path = os.path.join('data','output', 'outputgray.png')

# %%
cv2.imwrite(output_path, gray)
